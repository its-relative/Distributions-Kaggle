# %% [markdown]
# **This notebook is an exercise in the [Data Visualization](https://www.kaggle.com/learn/data-visualization) course.  You can reference the tutorial at [this link](https://www.kaggle.com/alexisbcook/final-project).**
#
# ---

# %% [markdown]
# Now it's time for you to demonstrate your new skills with a project of your own!
#
# In this exercise, you will work with a dataset of your choosing.  Once you've selected a dataset, you'll design and create your own plot to tell interesting stories behind the data!
#
# ## Setup
#
# Run the next cell to import and configure the Python libraries that you need to complete the exercise.

# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
print("Setup Complete")
# Out:
# Setup Complete

# %% [markdown]
# The questions below will give you feedback on your work. Run the following cell to set up the feedback system.

# %%
# Set up code checking
from learntools.core import binder
binder.bind(globals())
from learntools.data_viz_to_coder.ex7 import *
print("Setup Complete")
# Out:
# Setup Complete

# %% [markdown]
# ## Step 1: Attach a dataset to the notebook
#
# Begin by selecting a CSV dataset from [Kaggle Datasets](https://www.kaggle.com/datasets).  If you're unsure how to do this, please revisit the instructions in the previous tutorial.
#
# Once you have selected a dataset, click on the **[+ Add data]** option in the top right corner.  This will generate a pop-up window that you can use to search for your chosen dataset.
#
# ![ex6_search_dataset](https://storage.googleapis.com/kaggle-media/learn/images/cIIWPUS.png)
#
# Once you have found the dataset, click on the **[Add]** button to attach it to the notebook.  You can check that it was successful by looking at the **Data** dropdown menu to the right of the notebook -- look for an **input** folder containing a subfolder that matches the name of the dataset.
#
# <center>
# <img src="https://storage.googleapis.com/kaggle-media/learn/images/nMYc1Nu.png" width=30%><br/>
# </center>
#
# You can click on the carat to the left of the name of the dataset to double-check that it contains a CSV file.  For instance, the image below shows that the example dataset contains two CSV files: (1) **dc-wikia-data.csv**, and (2) **marvel-wikia-data.csv**.
#
# <center>
# <img src="https://storage.googleapis.com/kaggle-media/learn/images/B4sJkVA.png" width=30%><br/>
# </center>
#
# Once you've uploaded a dataset with a CSV file, run the code cell below **without changes** to receive credit for your work!

# %%
# Check for a dataset with a CSV file
step_1.check()
# Out:
# Correct:

# %% [markdown]
# ## Step 2: Specify the filepath
#
# Now that the dataset is attached to the notebook, you can find its filepath.  To do this, begin by clicking on the CSV file you'd like to use.  This will open the CSV file in a tab below the notebook.  You can find the filepath towards the top of this new tab.
#
# ![ex6_filepath](https://storage.googleapis.com/kaggle-media/learn/images/fgXQV47.png)
#
# After you find the filepath corresponding to your dataset, fill it in as the value for `my_filepath` in the code cell below, and run the code cell to check that you've provided a valid filepath.  For instance, in the case of this example dataset, we would set
# ```
# my_filepath = "../input/fivethirtyeight-comic-characters-dataset/dc-wikia-data.csv"
# ```
# Note that **you must enclose the filepath in quotation marks**; otherwise, the code will return an error.
#
# Once you've entered the filepath, you can close the tab below the notebook by clicking on the **[X]** at the top of the tab.

# %%
# Fill in the line below: Specify the path of the CSV file to read
my_filepath = "/kaggle/input/literacy-data-2011/Literacy Data 2011.csv"

# Check for a valid filepath to a CSV file in a dataset
step_2.check()
# Out:
# Correct:

# %% [markdown]
# ## Step 3: Load the data
#
# Use the next code cell to load your data file into `my_data`.  Use the filepath that you specified in the previous step.

# %%
# Fill in the line below: Read the file into a variable my_data
my_data = pd.read_csv(my_filepath, index_col = "Unnamed: 0")

# Check that a dataset has been uploaded into my_data
step_3.check()
# Out:
# Correct:

# %%
df = my_data.copy()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 640 entries, 1 to 640
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   District  640 non-null    object
#  1   State     640 non-null    object
#  2   Literacy  640 non-null    float64
# dtypes: float64(1), object(2)
# memory usage: 20.0+ KB

# %%
df.head()
# Out:
#                       District         State  Literacy
# 1                        Thane   Maharashtra     84.53
# 2   North Twenty Four Parganas   West Bengal     84.06
# 3                    Bangalore     Karnataka     87.67
# 4                         Pune   Maharashtra     86.15
# 5              Mumbai Suburban   Maharashtra     89.91

# %%
df.columns
# Out:
# Index(['District', 'State', 'Literacy'], dtype='object')

# %% [markdown]
# **_After the code cell above is marked correct_**, run the code cell below without changes to view the first five rows of the data.

# %%
# Print the first five rows of the data
my_data.head(5)
# Out:
#                       District         State  Literacy
# 1                        Thane   Maharashtra     84.53
# 2   North Twenty Four Parganas   West Bengal     84.06
# 3                    Bangalore     Karnataka     87.67
# 4                         Pune   Maharashtra     86.15
# 5              Mumbai Suburban   Maharashtra     89.91

# %%
df["State"].unique()
# Out:
# array([' Maharashtra', ' West Bengal', ' Karnataka', ' Gujarat',
#        ' Rajasthan', ' Uttar Pradesh', ' Bihar', ' Andhra Pradesh',
#        ' Tamil Nadu', ' Kerala', ' Chhattisgarh', ' Delhi', ' Orissa',
#        ' Punjab', ' Madhya Pradesh', ' Jharkhand', ' Assam',
#        ' Uttarakhand', ' Haryana', ' Tripura', ' Jammu and Kashmir',
#        ' Himachal Pradesh', ' Chandigarh', ' Puducherry', ' Meghalaya',
#        ' Goa', ' Manipur', ' Mizoram', ' Nagaland',
#        ' Dadra and Nagar Haveli', ' Sikkim',
#        ' Andaman And Nicobar Islands', ' Daman and Diu',
#        ' Arunachal Pradesh', ' Lakshadweep'], dtype=object)

# %%
df["District"].unique()
# Out:
# array([' Thane', ' North Twenty Four Parganas', ' Bangalore', ' Pune',
#        ' Mumbai Suburban', ' South Twenty Four Parganas', ' Barddhaman',
#        ' Ahmadabad', ' Murshidabad', ' Jaipur', ' Nashik', ' Surat',
#        ' Allahabad', ' Paschim Medinipur', ' Patna', ' Hugli',
#        ' Rangareddy', ' Nadia', ' East Godavari', ' Purbi Champaran',
#        ' Purba Medinipur', ' Guntur', ' Haora', ' Muzaffarpur',
#        ' Belgaum', ' Moradabad', ' Ghaziabad', ' Nagpur', ' Chennai',
#        ' Azamgarh', ' Lucknow', ' Kanpur Nagar', ' Ahmadnagar',
#        ' Krishna', ' Kolkata', ' Jaunpur', ' Madhubani', ' Sitapur',
#        ' Bareilly', ' Gorakhpur', ' Agra', ' Gaya', ' Solapur',
#        ' Visakhapatnam', ' Samastipur', ' Jalgaon', ' Chittoor',
#        ' Vadodara', ' Muzaffarnagar', ' Malappuram', ' Hardoi',
#        ' Anantapur', ' Raipur', ' Kurnool', ' Mahbubnagar', ' Kheri',
#        ' Kancheepuram', ' Maldah', ' Saran', ' Hyderabad', ' Darbhanga',
#        ' West Godavari', ' Vellore', ' Pashchim Champaran', ' Kolhapur',
#        ' Jalpaiguri', ' Rajkot', ' Sultanpur', ' Karimnagar',
#        ' Thiruvallur', ' Aurangabad', ' Jodhpur', ' Bijnor', ' Budaun',
#        ' Varanasi', ' Alwar', ' Aligarh', ' North West Delhi',
#        ' Ghazipur', ' Bankura', ' Kushinagar', ' Ganjam', ' Warangal',
#        ' Birbhum', ' Bulandshahar', ' Ludhiana', ' Vaishali', ' Nalgonda',
#        ' Bahraich', ' Salem', ' Saharanpur', ' Viluppuram', ' Coimbatore',
#        ' Meerut', ' Gonda', ' Sitamarhi', ' Rae Bareli', ' Prakasam',
#        ' Nanded', ' Durg', ' Siwan', ' Nagaur', ' Thiruvananthapuram',
#        ' Ernakulam', ' Indore', ' Purnia', ' Barabanki', ' Ballia',
#        ' Pratapgarh', ' Thrissur', ' Banaskantha', ' Unnao', ' Deoria',
#        ' Kozhikode', ' Mumbai City', ' Tirunelveli', ' Katihar',
#        ' Udaipur', ' Madurai', ' Bhagalpur', ' Medak', ' Uttar Dinajpur',
#        ' Shahjahanpur', ' Satara', ' Mysore', ' Begusarai',
#        ' Sri Potti Sriramulu Nellore', ' Rohtas', ' Puruliya', ' Ranchi',
#        ' Amravati', ' YSR', ' Bhavnagar', ' Nalanda', ' Nagaon',
#        ' Sangli', ' Koch Bihar', ' Araria', ' Palakkad', ' Khammam',
#        ' Yavatmal', ' Junagadh', ' Adilabad', ' South Delhi', ' Bhojpur',
#        ' Tiruchirappalli', ' Srikakulam', ' Maharajganj', ' Dhanbad',
#        ' Tumkur', ' Sikar', ' Bilaspur', ' Kollam', ' Raigarh',
#        ' Fatehpur', ' Cuttack', ' Cuddalore', ' Barmer', ' Buldana',
#        ' Bid', ' Ajmer', ' Gulbarga', ' Gopalganj', ' Siddharth Nagar',
#        ' Nizamabad', ' Bharatpur', ' Mathura', ' West Delhi', ' Kannur',
#        ' Mayurbhanj', ' Firozabad', ' Mirzapur', ' Amritsar', ' Tiruppur',
#        ' Faizabad', ' Tiruvannamalai', ' Basti', ' Jabalpur', ' Latur',
#        ' Bellary', ' Giridih', ' Sabarkantha', ' Bhilwara', ' Thanjavur',
#        ' Ambedkar Nagar', ' PanchMahal', ' Sagar', ' Bhopal', ' Rewa',
#        ' Bikaner', ' Surguja', ' Vizianagaram', ' Rampur', ' Baleshwar',
#        ' Kheda', ' Gurdaspur', ' Purbi Singhbhum', ' South West Delhi',
#        ' Erode', ' Khordha', ' North East Delhi', ' Supaul', ' Satna',
#        ' Nawada', ' Mau', ' Chandrapur', ' Jalandhar', ' Dhar',
#        ' Bijapur', ' Jamnagar', ' Dindigul', ' Balrampur', ' Jhunjhunun',
#        ' Alappuzha', ' Dohad', ' Sundargarh', ' Anand', ' Kachchh',
#        ' Chhindwara', ' Dakshina Kannada', ' Bokaro', ' Dhule', ' Churu',
#        ' Pali', ' Mahesana', ' Banka', ' Gwalior', ' Pilibhit',
#        ' Firozpur', ' Madhepura', ' Jhansi', ' Ujjain', ' Kottayam',
#        ' Ganganagar', ' Morena', ' Jalna', ' Chandauli', ' Kota',
#        ' Dhubri', ' Davanagere', ' Virudhunagar', ' Palamu', ' Raichur',
#        ' Sonitpur', ' Saharsa', ' Patiala', ' Haridwar', ' Bagalkot',
#        ' Farrukhabad', ' Krishnagiri', ' West Nimar', ' Kanniyakumari',
#        ' Mainpuri', ' Sonbhadra', ' Dharwad', ' Darjiling',
#        ' Jyotiba Phule Nagar', ' Parbhani', ' Jalor', ' Jajapur',
#        ' Akola', ' Faridabad', ' Mandya', ' Kendujhar', ' Banda',
#        ' Banswara', ' Ramabai Nagar', ' Hassan', ' Hanumangarh', ' Etah',
#        ' Chhattarpur', ' Jamui', ' Surendranagar', ' Shimoga',
#        ' Thoothukkudi', ' Hisar', ' Cachar', ' Hazaribagh', ' Namakkal',
#        ' Shivpuri', ' West Tripura', ' Sant Kabir Nagar', ' East Delhi',
#        ' Buxar', ' Valsad', ' Bidar', ' Bhind', ' Balaghat', ' Puri',
#        ' Dehradun', ' Barpeta', ' Kishanganj', ' Jalaun',
#        ' Dakshin Dinajpur', ' Khagaria', ' Chitradurga', ' Osmanabad',
#        ' Kannauj', ' Sangrur', ' Balangir', ' Udham Singh Nagar',
#        ' Nandurbar', ' Gautam Buddha Nagar', ' Bhiwani', ' Dausa',
#        ' Kaimur', ' Janjgir Champa', ' Pudukkottai', ' Nagapattinam',
#        ' Ratnagiri', ' Kaushambi', ' Haveri', ' Hoshiarpur', ' Etawah',
#        ' Sant Ravidas Nagar', ' Kalahandi', ' Betul', ' Mahamaya Nagar',
#        ' Dewas', ' Bharuch', ' Rajgarh', ' Chittaurgarh', ' Rajnandgaon',
#        ' Kolar', ' Jammu', ' Kamrup', ' Gurgaon', ' Amreli', ' Shajapur',
#        ' Kangra', ' Dharmapuri', ' Bhadrak', ' Karnal',
#        ' Pashchimi Singhbhum', ' Deoghar', ' Bargarh', ' Vidisha',
#        ' Karauli', ' Ratlam', ' Sonipat', ' Tikamgarh', ' Kendrapara',
#        ' Uttara Kannada', ' Kanshiram Nagar', ' Tonk', ' Bastar',
#        ' Jhalawar', ' Gandhinagar', ' Koppal', ' Dungarpur', ' Bathinda',
#        ' Barwani', ' Koraput', ' Auraiya', ' Seoni', ' Munger',
#        ' Ramanathapuram', ' Patan', ' Mandsaur', ' Sivaganga',
#        ' Sawai Madhopur', ' Jind', ' Raisen', ' Navsari', ' Tinsukia',
#        ' Dibrugarh', ' Garhwa', ' Gondiya', ' Dumka', ' Godda', ' Sehore',
#        ' East Nimar', ' Kasaragod', ' Baghpat', ' Wardha', ' Sirsa',
#        ' Katni', ' Anugul', ' Thiruvarur', ' Damoh', ' Chikkaballapura',
#        ' Kamrup Metropolitan', ' Theni', ' Guna', ' Hoshangabad',
#        ' Srinagar', ' Karimganj', ' Baran', ' Lalitpur', ' Nabarangapur',
#        ' Yamunanagar', ' Korba', ' Dhaulpur', ' Panipat', ' Bhandara',
#        ' Pathanamthitta', ' Washim', ' Dhenkanal', ' Singrauli', ' Udupi',
#        ' Hingoli', ' Yadgir', ' Rajsamand', ' Sivasagar', ' Sahibganj',
#        ' Chikmagalur', ' Jagatsinghapur', ' Ambala', ' Sidhi',
#        ' Jehanabad', ' Tarn Taran', ' Shrawasti', ' Bundi', ' Idukki',
#        ' Hamirpur', ' Jorhat', ' Narsimhapur', ' Mewat', ' Ramanagara',
#        ' Anantnag', ' Kaithal', ' Gadchiroli', ' Golaghat', ' Shahdol',
#        ' Saraikela Kharsawan', ' Gadag', ' Karur', ' Rohtak',
#        ' Chandigarh', ' Mandla', ' Chatra', ' Palwal', ' Lakhimpur',
#        ' Sambalpur', ' Sirohi', ' Mahasamund', ' Gumla', ' Jhabua',
#        ' Chamarajanagar', ' Panna', ' Goalpara', ' Baramula',
#        ' Lakhisarai', ' Mandi', ' Moga', ' Mohali', ' Chitrakoot',
#        ' Bangalore Rural', ' Rayagada', ' Kurukshetra', ' Nayagarh',
#        ' Jhajjar', ' Morigaon', ' Karbi Anglong', ' Nainital',
#        ' Puducherry', ' Baksa', ' Ramgarh', ' Fatehabad', ' Darrang',
#        ' Mahendragarh', ' Muktsar', ' Pakur', ' Rewari', ' North Delhi',
#        ' Kokrajhar', ' South Tripura', ' Mahoba', ' Kupwara', ' Jashpur',
#        ' Sindhudurg', ' Ashoknagar', ' Udalguri', ' Neemuch',
#        ' East Khasi Hills', ' Kabirdham', ' North Goa', ' Wayanad',
#        ' Kapurthala', ' Shimla', ' Tapi', ' Dhamtari', ' Jamtara',
#        ' Datia', ' Nalbari', ' Mansa', ' Burhanpur', ' Ariyalur',
#        ' Badgam', ' Anuppur', ' Kanker', ' Bongaigaon', ' The Nilgiris',
#        ' Kandhamal', ' Alirajpur', ' Latehar', ' Kodarma', ' Dindori',
#        ' Arwal', ' North Tripura', ' Sheopur', ' Pauri Garhwal',
#        ' Dhemaji', ' Rupnagar', ' Jaisalmer', ' Hailakandi', ' Korea',
#        ' Sheohar', ' Umaria', ' West Garo Hills', ' Rajouri',
#        ' South Goa', ' Sheikhpura', ' Almora', ' Tehri Garhwal',
#        ' Faridkot', ' Kathua', ' Malkangiri',
#        ' Shahid Bhagat Singh Nagar', ' Nuapada', ' Subarnapur',
#        ' Fatehgarh Sahib', ' Simdega', ' Barnala', ' Narmada',
#        ' Porbandar', ' Central Delhi', ' Solan', ' Jharsuguda',
#        ' Gajapati', ' Harda', ' Perambalur', ' Panchkula', ' Pulwama',
#        ' Udhampur', ' Kodagu', ' Dantewada', ' Khunti', ' Sirmaur',
#        ' Una', ' Chamba', ' Imphal West', ' Pithoragarh', ' Chirang',
#        ' Senapati', ' Punch', ' Lohardaga', ' Imphal East', ' Baudh',
#        ' Kullu', ' Kulgam', ' Thoubal', ' Doda', ' Aizawl',
#        ' Jaintia Hills', ' Bandipora', ' Chamoli', ' West Khasi Hills',
#        ' Dimapur', ' Dhalai', ' Dadra and Nagar Haveli', ' Uttarkashi',
#        ' Samba', ' East Garo Hills', ' Reasi', ' Debagarh', ' Ganderbal',
#        ' Ramban', ' East Sikkim', ' Churachandpur', ' Kohima',
#        ' Shupiyan', ' Bageshwar', ' Champawat', ' Ri Bhoi', ' Mon',
#        ' Rudraprayag', ' South Andaman', ' Bishnupur', ' Kishtwar',
#        ' The Dangs', ' Dima Hasao', ' Karaikal', ' Tuensang',
#        ' Mokokchung', ' Daman', ' Ukhrul', ' Papumpare', ' Wokha',
#        ' Phek', ' Lunglei', ' Changlang', ' South Sikkim', ' Lohit',
#        ' Chandel', ' South Garo Hills', ' New Delhi', ' Kargil',
#        ' Zunheboto', ' Tamenglong', ' Narayanpur', ' West Sikkim', ' Leh',
#        ' Champhai', ' Lawngtlai', ' West Siang', ' Tirap',
#        ' North And Middle Andaman', ' East Siang', ' Peren',
#        ' Kurung Kumey', ' Mamit', ' Kinnaur', ' Kolasib', ' West Kameng',
#        ' Upper Subansiri', ' Lower Subansiri', ' East Kameng', ' Kiphire',
#        ' Serchhip', ' Lakshadweep', ' Saiha', ' Yanam',
#        ' Lower Dibang Valley', ' Diu', ' Longleng', ' Tawang',
#        ' North Sikkim', ' Mahe', ' Nicobars', ' Upper Siang',
#        ' Lahul and Spiti', ' Anjaw', ' Dibang Valley'], dtype=object)

# %% [markdown]
# ## Step 4: Visualize the data
#
# Use the next code cell to create a figure that tells a story behind your dataset.  You can use any chart type (_line chart, bar chart, heatmap, etc_) of your choosing!

# %%
# df['State']
plt.figure(figsize = (10,14))
sns.barplot(data = df, y = df["State"] , x = df["Literacy"])
# plt.xticks(rotation = 90)
plt.plot()
# Out:
# []

# %%
plt.figure(figsize = (14,10))
sns.boxplot(data = df, y = df['State'], x = "Literacy")
# Out:
# <Axes: xlabel='Literacy', ylabel='State'>

# %%
import pandas as pd

# %%
df.head()
# Out:
#                       District         State  Literacy
# 1                        Thane   Maharashtra     84.53
# 2   North Twenty Four Parganas   West Bengal     84.06
# 3                    Bangalore     Karnataka     87.67
# 4                         Pune   Maharashtra     86.15
# 5              Mumbai Suburban   Maharashtra     89.91

# %%
# dfg.index

# %%
dfg = df.groupby(["State"])["Literacy"].mean()
sns.barplot(data = dfg, y = dfg.index , x = dfg.values)
# dfg.head()
# Out:
# <Axes: ylabel='Literacy'>

# %%
dfg.index
# Out:
# Index([' Andaman And Nicobar Islands', ' Andhra Pradesh', ' Arunachal Pradesh',
#        ' Assam', ' Bihar', ' Chandigarh', ' Chhattisgarh',
#        ' Dadra and Nagar Haveli', ' Daman and Diu', ' Delhi', ' Goa',
#        ' Gujarat', ' Haryana', ' Himachal Pradesh', ' Jammu and Kashmir',
#        ' Jharkhand', ' Karnataka', ' Kerala', ' Lakshadweep',
#        ' Madhya Pradesh', ' Maharashtra', ' Manipur', ' Meghalaya', ' Mizoram',
#        ' Nagaland', ' Orissa', ' Puducherry', ' Punjab', ' Rajasthan',
#        ' Sikkim', ' Tamil Nadu', ' Tripura', ' Uttar Pradesh', ' Uttarakhand',
#        ' West Bengal'],
#       dtype='object', name='State')

# %%
# Create a plot
# ____ # Your code here
# df['State']
plt.figure(figsize = (10,14))
sns.barplot(data = df, y = df["State"] , x = df["Literacy"])
# plt.xticks(rotation = 90)
plt.plot()

# Check that a figure appears below
step_4.check()
# Out:
# Correct:

# %% [markdown]
# ## Keep going
#
# Learn how to use your skills after completing the micro-course to create data visualizations in a **[final tutorial](https://www.kaggle.com/alexisbcook/creating-your-own-notebooks)**.

# %% [markdown]
# ---
#
#
#
#
# *Have questions or comments? Visit the [course discussion forum](https://www.kaggle.com/learn/data-visualization/discussion) to chat with other learners.*
